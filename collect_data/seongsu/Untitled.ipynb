# %%
import requests  # HTTP 통신용
import json      # JSON 직렬화/역직렬화용

# %%
api_server =     'https://apis.data.go.kr/1160100/service/GetStockSecuritiesInfoService/' 
service_type = 'getStockPriceInfo?'
api_keys = 'serviceKey=GA311E%2BcoIjThrHBk%2BS%2FQv1rdezbmls5F4RMdBYZSnSpx0xj%2ByCBBuytW%2FLNQJON2NPk%2Feam%2B63aYq5WkLLzMw%3D%3D&'
result_type = 'resultType=json'

API_SERVER = api_server + service_type + api_keys + result_type
print(API_SERVER)
#try:
#    response = requests.get(API_SERVER)
#except requests.exceptions.RequestException as e:
#        print(f" 서버 연결 오류: {e}\n")
#if response.status_code == 200:
#    result = response.json()
#    print(result)
# Out:
# https://apis.data.go.kr/1160100/service/GetStockSecuritiesInfoService/getStockPriceInfo?serviceKey=GA311E%2BcoIjThrHBk%2BS%2FQv1rdezbmls5F4RMdBYZSnSpx0xj%2ByCBBuytW%2FLNQJON2NPk%2Feam%2B63aYq5WkLLzMw%3D%3D&resultType=json
